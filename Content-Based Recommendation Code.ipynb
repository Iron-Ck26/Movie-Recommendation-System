# %%
import numpy as np
import pandas as pd
import re

# %%
credits = pd.read_csv("D:\\Class Projects\\Jupyter Notebook\\Movie Preadiction\\Content Based\\Data File\\Content\\tmdb_5000_credits.csv")
movies = pd.read_csv("D:\\Class Projects\\Jupyter Notebook\\Movie Preadiction\\Content Based\\Data File\\Content\\tmdb_5000_movies.csv")

# %%
credits.head()
# Out:
#    movie_id                                     title  \
# 0     19995                                    Avatar
# 1       285  Pirates of the Caribbean: At World's End
# 2    206647                                   Spectre
# 3     49026                     The Dark Knight Rises
# 4     49529                               John Carter
#
#                                                 cast  \
# 0  [{"cast_id": 242, "character": "Jake Sully", "...
# 1  [{"cast_id": 4, "character": "Captain Jack Spa...
# 2  [{"cast_id": 1, "character": "James Bond", "cr...
# 3  [{"cast_id": 2, "character": "Bruce Wayne / Ba...
# 4  [{"cast_id": 5, "character": "John Carter", "c...
#
#                                                 crew
# 0  [{"credit_id": "52fe48009251416c750aca23", "de...
# 1  [{"credit_id": "52fe4232c3a36847f800b579", "de...
# 2  [{"credit_id": "54805967c3a36829b5002c41", "de...
# 3  [{"credit_id": "52fe4781c3a36847f81398c3", "de...
# ...

# %%
movies.head()
# Out:
#       budget                                             genres  \
# 0  237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1  300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2  245000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 3  250000000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4  260000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
#
#                                        homepage      id  \
# 0                   http://www.avatarmovie.com/   19995
# 1  http://disney.go.com/disneypictures/pirates/     285
# 2   http://www.sonypictures.com/movies/spectre/  206647
# 3            http://www.thedarkknightrises.com/   49026
# 4          http://movies.disney.com/john-carter   49529
#
#                                             keywords original_language  \
# 0  [{"id": 1463, "name": "culture clash"}, {"id":...                en
# 1  [{"id": 270, "name": "ocean"}, {"id": 726, "na...                en
# ...

# %%
movies_column_renamed = movies.rename(index=str, columns={'id':'movie_id'})
movies_df_merge = movies_column_renamed.merge(credits, on='movie_id')
movies_df_merge.head()
# Out:
#       budget                                             genres  \
# 0  237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1  300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2  245000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 3  250000000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4  260000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
#
#                                        homepage  movie_id  \
# 0                   http://www.avatarmovie.com/     19995
# 1  http://disney.go.com/disneypictures/pirates/       285
# 2   http://www.sonypictures.com/movies/spectre/    206647
# 3            http://www.thedarkknightrises.com/     49026
# 4          http://movies.disney.com/john-carter     49529
#
#                                             keywords original_language  \
# 0  [{"id": 1463, "name": "culture clash"}, {"id":...                en
# 1  [{"id": 270, "name": "ocean"}, {"id": 726, "na...                en
# ...

# %%
movies_cleaned_df = movies_df_merge.drop(columns=[ 'title_x', 'title_y', 'status','production_countries'])
movies_cleaned_df.head()
# Out:
#       budget                                             genres  \
# 0  237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1  300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2  245000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 3  250000000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4  260000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
#
#                                        homepage  movie_id  \
# 0                   http://www.avatarmovie.com/     19995
# 1  http://disney.go.com/disneypictures/pirates/       285
# 2   http://www.sonypictures.com/movies/spectre/    206647
# 3            http://www.thedarkknightrises.com/     49026
# 4          http://movies.disney.com/john-carter     49529
#
#                                             keywords original_language  \
# 0  [{"id": 1463, "name": "culture clash"}, {"id":...                en
# 1  [{"id": 270, "name": "ocean"}, {"id": 726, "na...                en
# ...

# %%
movies_cleaned_df.isnull().sum()
# Out:
# budget                     0
# genres                     0
# homepage                3091
# movie_id                   0
# keywords                   0
# original_language          0
# original_title             0
# overview                   3
# popularity                 0
# production_companies       0
# release_date               1
# revenue                    0
# runtime                    2
# spoken_languages           0
# tagline                  844
# vote_average               0
# vote_count                 0
# cast                       0
# crew                       0
# dtype: int64

# %%
movies_cleaned_df['homepage'] = movies_cleaned_df['homepage'].fillna('Note Defind')

# %%
movies_cleaned_df['overview'] = movies_cleaned_df['overview'].fillna('')

# %%
movies_cleaned_df.head(5)['overview']
# Out:
# 0    In the 22nd century, a paraplegic Marine is di...
# 1    Captain Barbossa, long believed to be dead, ha...
# 2    A cryptic message from Bond’s past sends him o...
# 3    Following the death of District Attorney Harve...
# 4    John Carter is a war-weary, former military ca...
# Name: overview, dtype: object

# %%
from sklearn.feature_extraction.text import TfidfVectorizer


tfv = TfidfVectorizer(min_df=3,  max_features=None, 
            strip_accents='unicode', analyzer='word',token_pattern=r'\w{1,}',
            ngram_range=(1, 3),
            stop_words = 'english')

# %%
movies_cleaned_df.head(10)
# Out:
#       budget                                             genres  \
# 0  237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1  300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2  245000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 3  250000000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4  260000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 5  258000000  [{"id": 14, "name": "Fantasy"}, {"id": 28, "na...
# 6  260000000  [{"id": 16, "name": "Animation"}, {"id": 10751...
# 7  280000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 8  250000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 9  250000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
#
#                                             homepage  movie_id  \
# 0                        http://www.avatarmovie.com/     19995
# 1       http://disney.go.com/disneypictures/pirates/       285
# 2        http://www.sonypictures.com/movies/spectre/    206647
# ...

# %%
movies_cleaned_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4803 entries, 0 to 4802
# Data columns (total 19 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   budget                4803 non-null   int64
#  1   genres                4803 non-null   object
#  2   homepage              4803 non-null   object
#  3   movie_id              4803 non-null   int64
#  4   keywords              4803 non-null   object
#  5   original_language     4803 non-null   object
#  6   original_title        4803 non-null   object
#  7   overview              4803 non-null   object
#  8   popularity            4803 non-null   float64
#  9   production_companies  4803 non-null   object
#  10  release_date          4802 non-null   object
#  11  revenue               4803 non-null   int64
#  12  runtime               4801 non-null   float64
#  13  spoken_languages      4803 non-null   object
#  14  tagline               3959 non-null   object
# ...

# %%
movies_extract_df = pd.DataFrame(movies_cleaned_df)

# %%
movies_extract_df.head(10)
# Out:
#       budget                                             genres  \
# 0  237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1  300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2  245000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 3  250000000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4  260000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 5  258000000  [{"id": 14, "name": "Fantasy"}, {"id": 28, "na...
# 6  260000000  [{"id": 16, "name": "Animation"}, {"id": 10751...
# 7  280000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 8  250000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 9  250000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
#
#                                             homepage  movie_id  \
# 0                        http://www.avatarmovie.com/     19995
# 1       http://disney.go.com/disneypictures/pirates/       285
# 2        http://www.sonypictures.com/movies/spectre/    206647
# ...

# %%
target_words = ['Action', 'Animation', 'Adventure', 'Fantasy', 'Science Fiction', 'Drama', 'Thriller','Family']

# %%
def extract_target_words(text, target_words):
    extracted_genres = []
    for target_words in target_words:
        match = re.search(rf'\b{re.escape(target_words)}\b', text, re.IGNORECASE)
        if match:
            extracted_genres.append(match.group())
    return extracted_genres if extracted_genres else None

# %%
#def extract_target_word(text, target_word):
    #match = re.search(rf'\b{re.escape(target_words)}\b', text, re.IGNORECASE)
    #if match:
        #return match.group()
    #else:
        #return None

# %%
movies_extract_df['extracted_genres'] = movies_extract_df['genres'].apply(lambda x: extract_target_words(x, target_words))
print(movies_extract_df['extracted_genres'])
# Out:
# 0       [Action, Adventure, Fantasy, Science Fiction]
# 1                        [Action, Adventure, Fantasy]
# 2                                 [Action, Adventure]
# 3                           [Action, Drama, Thriller]
# 4                [Action, Adventure, Science Fiction]
#                             ...
# 4798                               [Action, Thriller]
# 4799                                             None
# 4800                                          [Drama]
# 4801                                             None
# 4802                                             None
# Name: extracted_genres, Length: 4803, dtype: object

# %%
movies_extract_df['overview'] = movies_extract_df['overview'].fillna('NA')

# %%
movies_extract_df.head(10)
# Out:
#       budget                                             genres  \
# 0  237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1  300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2  245000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 3  250000000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4  260000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 5  258000000  [{"id": 14, "name": "Fantasy"}, {"id": 28, "na...
# 6  260000000  [{"id": 16, "name": "Animation"}, {"id": 10751...
# 7  280000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 8  250000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 9  250000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
#
#                                             homepage  movie_id  \
# 0                        http://www.avatarmovie.com/     19995
# 1       http://disney.go.com/disneypictures/pirates/       285
# 2        http://www.sonypictures.com/movies/spectre/    206647
# ...

# %%
# Fitting the TF-IDF on the 'overview' text
tfv_matrix = tfv.fit_transform(movies_extract_df['overview'])
tfv_matrix
# Out:
# <4803x10417 sparse matrix of type '<class 'numpy.float64'>'
# 	with 127220 stored elements in Compressed Sparse Row format>

# %%
from sklearn.metrics.pairwise import sigmoid_kernel

#Compute the sigmoid kernel
sig = sigmoid_kernel(tfv_matrix, tfv_matrix)

# %%
# Reverse mapping of indices and movie titles
indices = pd.Series(movies_extract_df.index, index=movies_cleaned_df['original_title']).drop_duplicates()

# %%
def give_rec(title, sig=sig):
    # Get the index corresponding to original_title
    idx = indices[title]

    # Get the pairwsie similarity scores 
    sig_scores = list(enumerate(sig[idx]))
  

    # Sort the movies 
    sig_scores = sorted(sig_scores, key=lambda x: x[1], reverse=True)

    # Scores of the 10 most similar movies
    sig_scores = sig_scores[1:11]

    # Movie indices
    movie_indices = [i[0] for i in sig_scores]

    # Top 10 most similar movies
    recommended_movies = movies_extract_df.iloc[movie_indices][['original_title', 'homepage', 'extracted_genres']]
    return recommended_movies

# %%
#movie_title = input()
#recommended_movies = give_rec(movie_title)'
#print(recommended_movies)

# %%
# Testing our content-based recommendation system with the seminal film Spy Kids
give_rec(input())
# Out:
# Harry Potter and the Half-Blood Prince
#                                  original_title  \
# 114         Harry Potter and the Goblet of Fire
# 113   Harry Potter and the Order of the Phoenix
# 1205                           The Skeleton Key
# 4133                                      Plush
# 4568    Poultrygeist: Night of the Chicken Dead
# 191    Harry Potter and the Prisoner of Azkaban
# 4756                        The Call of Cthulhu
# 276     Harry Potter and the Chamber of Secrets
# 197    Harry Potter and the Philosopher's Stone
# 501                           The Little Prince
#
#                                                homepage  \
# 114                  http://harrypotter.warnerbros.com/
# 113        http://www.harrypotterorderofthephoenix.com/
# 1205                                        Note Defind
# 4133                          http://plushthemovie.com/
# 4568                                        Note Defind
# ...
